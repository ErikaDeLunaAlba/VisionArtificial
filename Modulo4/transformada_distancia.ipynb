# %%
import cv2
import numpy as np

# %%
imagen = cv2.imread("img/lena.jpeg", cv2.IMREAD_GRAYSCALE)
_,imagen_bin = cv2.threshold(imagen, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2.imshow("Imagen", imagen_bin)
cv2.waitKey(0)
# Out:
# -1

# %%
# Matriz de prueba

imagen_bin = np.matrix([
    [1,1,1],
    [1,0,1],
    [1,1,1]
]).astype(np.uint8)
imagen_bin
# Out:
# matrix([[1, 1, 1],
#         [1, 0, 1],
#         [1, 1, 1]], dtype=uint8)

# %%
h, w = imagen_bin.shape
matriz_distancias = (h + w) * imagen_bin.astype(np.uint16)
matriz_distancias
# Out:
# matrix([[6, 6, 6],
#         [6, 0, 6],
#         [6, 6, 6]])

# %%
# Primera pasada
for y in range(h):
    for x in range(w):
        norte = y - 1
        oeste = x - 1
        if norte < h and norte >= 0:
            pixel_norte = matriz_distancias[norte, x]
        else:
            pixel_norte = h + w
        if oeste < w and oeste >= 0:
            pixel_oeste = matriz_distancias[y, oeste]
        else:
            pixel_oeste = h + w
    
        matriz_distancias[y,x] = min(matriz_distancias[y,x], pixel_norte + 1, pixel_oeste + 1)

print(matriz_distancias)
# Out:
# [[6 6 6]
#  [6 0 1]
#  [6 1 2]]

# %%
# Segunda Pasada
for y in range(h-1, -1, -1):
    for x in range(w-1, -1, -1):
        sur = y + 1
        este = x + 1
        if sur < h and sur >= 0:
            pixel_sur = matriz_distancias[sur, x]
        else:
            pixel_sur = h + w
        if este < w and este >= 0:
            pixel_este = matriz_distancias[y, este]
        else:
            pixel_este = h + w
        
        matriz_distancias[y,x] = min(matriz_distancias[y,x], pixel_sur + 1, pixel_este + 1)

print(matriz_distancias)
# Out:
# [[2 1 2]
#  [1 0 1]
#  [2 1 2]]

# %%
matriz_distancias
# Out:
# matrix([[2, 1, 2],
#         [1, 0, 1],
#         [2, 1, 2]])

# %%
matriz_distancias_2 = cv2.distanceTransform(imagen_bin, cv2.DIST_L1, 3)

# %%
(matriz_distancias - matriz_distancias_2).sum()
# Out:
# np.float64(0.0)

# %%
# %pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in .\entorno4\Lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in .\entorno4\Lib\site-packages (from scikit-image) (2.4.2)
# Requirement already satisfied: scipy>=1.11.4 in .\entorno4\Lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in .\entorno4\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in .\entorno4\Lib\site-packages (from scikit-image) (12.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in .\entorno4\Lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in .\entorno4\Lib\site-packages (from scikit-image) (2026.3.3)
# Requirement already satisfied: packaging>=21 in .\entorno4\Lib\site-packages (from scikit-image) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in .\entorno4\Lib\site-packages (from scikit-image) (0.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from skimage.feature import peak_local_max
import cv2
import numpy as np

# Crear un array de ceros con la misma forma que la imagen binaria
skeleton = np.zeros(imagen_bin.shape, dtype=np.uint8)

# Encontrar los máximos locales en la matriz de distancias
coords = peak_local_max(matriz_distancias, min_distance=1)

# Marcar esos puntos en el esqueleto
for coord in coords:
    skeleton[coord[0], coord[1]] = 255

# Mostrar el resultado
cv2.imshow("Distancias", skeleton)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3 coords = peak_local_max(matriz_distancias, min_distance=1)
#       4 for coord in coords:
# ----> 5     skeleton[coord[0], coord[1]] = 255
#       6 cv2.imshow("Distancias", skeleton)
#       7 cv2.waitKey(0)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
